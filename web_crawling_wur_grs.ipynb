# %% [markdown]
# # Student Thesis Supervisor Matching

# %% [markdown]
# The problem to solve is matching student preferences to available supervisor slots. At the same time, each supervisor should have an equal number of students and each student should get their highest preference topic.

# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in /opt/homebrew/Cellar/jupyterlab/4.4.3/libexec/lib/python3.13/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in /opt/homebrew/Cellar/jupyterlab/4.4.3/libexec/lib/python3.13/site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/Cellar/jupyterlab/4.4.3/libexec/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/Cellar/jupyterlab/4.4.3/libexec/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/Cellar/jupyterlab/4.4.3/libexec/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Cellar/jupyterlab/4.4.3/libexec/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Extract supervisors and topics
#
# Topics and supervisors are collected from the website. Note that if people leave the group then the supervisor of the topic is not detected correctly as the contact for thesis coordination is automatically shown and falsely taken as supervisor.

# %%
import requests
import pandas as pd
import urllib.request
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import re

web_url = 'https://www.wur.nl'
topics_page_url = urljoin(web_url,'/en/research-results/chair-groups/environmental-sciences/laboratory-of-geo-information-science-and-remote-sensing/education/thesis/msc-thesis-topics/all-topics.htm?f46940599=')

topics_df = pd.DataFrame(columns=["ID", "Topic","Supervisor","Second Supervisor","Link","Max. Students"])

id_prefix = "mgi_24_"

supervisors_df = pd.DataFrame(columns=["ID", "Name","Titled","Role","Affiliation","Link","Max. Students"])

max_req = 0
topic_nr = 1
for i in range(0,130,10):
    response = requests.get(topics_page_url+str(i))
    soup = BeautifulSoup(response.text, 'html.parser')
    mylis = soup.find_all("li", {"class": "list-item"})
    for li in mylis:
        for topic_url in li.find_all('a'):
            full_topic_url = urljoin(web_url,topic_url.get('href'))
            print(full_topic_url)
            response = requests.get(full_topic_url)
            topic_soup = BeautifulSoup(response.text, 'html.parser')
            
            title = topic_soup.title.string.split(" - ")[0].split(":")[1]
            print(title)
            #print(topic_soup.prettify())
            reqs = topic_soup.find(string=re.compile(r'Requirements'))
            if (reqs):
                label = reqs.next_element 
                print(label)
                #print(labels.prettify())
                ul = label.find_all("li")
                if len(ul)>max_req:
                    max_req = len(ul)
                    print("Max reqs: " + str(max_req))
                    
                print("Requirements:")
                for li in ul:
                    print("- " + li.text)
            else:
                print("No requirements!")

            
            myaddresses = topic_soup.find_all("address", {"class": "vcard"})
            people = list()
            for address in myaddresses:
                myas = address.find_all("a", {"class": "navigation"})
                for a in myas:
                    print(a.get('title'))
                    full_person_url = urljoin(web_url,a.get('href'))
                    print(full_person_url)
                    people.append(full_person_url)

                    if not full_person_url in supervisors_df['Link'].values:
                        response = requests.get(full_person_url)
                        person_soup = BeautifulSoup(response.text, 'html.parser')

                        role = ""
                        mymetas = person_soup.find_all("meta", {"name": "position"})
                        for mymeta in mymetas:
                            print(mymeta.get('content'))
                            role = mymeta.get('content')

                        name = ""
                        affil = ""
                        mynavs = person_soup.find_all("nav", {"aria-label": "Breadcrumbs"})
                        for mynav in mynavs:
                            mylis2 = mynav.find_all("li", {"class": "breadcrumbs__crumb"})
                            for myli2 in mylis2:
                                #print(myli2.prettify)
                                if not myli2.find("a"):
                                    affil_name = myli2.string.split(" - ")
                                    affil = " ".join(affil_name[0].split())
                                    name = " ".join(affil_name[1].split())
                                    print(affil)
                                    print(name)
                        num_students = 1
                        role_lower = role.lower()
                        if "Geo-information" in affil:
                            if "professor" in role_lower:
                                num_students = 5
                            elif "universitair" in role_lower:
                                num_students = 5
                            elif "lecturer" in role_lower:
                                num_students = 3
                            elif "docent" in role_lower:
                                num_students = 3
                            elif "promovendus" in role_lower:
                                num_students = 1
                            elif "phd" in role_lower:
                                num_students = 1
                            else: #postdoc
                                num_students = 2
                        print(num_students)

                        person_entry = pd.DataFrame.from_dict({
                            "ID": [len(supervisors_df)],
                            "Name": [name],
                            "Titled": [a.get('title')],
                            "Role":  [role],
                            "Affiliation":  [affil],
                            "Link":[full_person_url],
                            "Max. Students":[num_students]
                        })
                        supervisors_df = pd.concat([supervisors_df, person_entry], ignore_index=True)
                    
            if len(people)==0:
                people.append("")
                people.append("")
            if len(people)==1:
                people.append("")

            
            entry = pd.DataFrame.from_dict({
                "ID": [id_prefix+f"{topic_nr:02d}"],
                "Topic": [title],
                "Supervisor":  [people[0]],
                "Second Supervisor":  [people[1]],
                "Link":[full_topic_url],
                "Max. Students":[1]
            })
            
            topics_df = pd.concat([topics_df, entry], ignore_index=True)
        topic_nr = topic_nr + 1
supervisors_df.to_csv("supervisors.csv")
topics_df.to_csv("topics.csv")
# Out:
# https://www.wur.nl/en/article/msc-thesis-topic-accuracy-of-forest-regrowth-dynamics-in-the-peruvian-amazon-using-the-avocado-algorithm.htm
#  Accuracy of forest regrowth dynamics in the Peruvian Amazon using the AVOCADO algorithm
# <ul><li>Advanced Earth Observation course</li><li>Geo-scripting course.</li><li>A lot of creativity.</li></ul>
# Max reqs: 3
# Requirements:
# - Advanced Earth Observation course
# - Geo-scripting course.
# - A lot of creativity.
# dr.ir. AI (Alvaro) Lau Sarmiento MSc
# https://www.wur.nl/en/persons/alvaro-lau-sarmiento-1.htm
# Docent
# Laboratory of Geo-information Science and Remote Sensing
# Alvaro Lau Sarmiento
# 3
# https://www.wur.nl/en/article/msc-thesis-topic-agent-based-modeling-and-simulation-of-shared-space-in-virtual-reality.htm
#  Agent-based modeling and simulation of shared space in virtual reality
# <ul><li>Interest in immersive technologies</li><li>Interest in technical development or empirical evaluations<br/></li></ul>
# Requirements:
# - Interest in immersive technologies
# - Interest in technical development or empirical evaluations
# J (Jiayan) Zhao PhD
# https://www.wur.nl/en/persons/jiayan-zhao.htm
# Universitair docent
# Laboratory of Geo-information Science and Remote Sensing
# Jiayan Zhao
# 5
# dr.ir. A (Arend) Ligtenberg
# https://www.wur.nl/en/persons/arend-ligtenberg.htm
# Assistant Professor
# Laboratory of Geo-information Science and Remote Sensing
# Arend Ligtenberg
# 5
# https://www.wur.nl/en/article/msc-thesis-topic-agent-based-simulation-of-the-forest-water-people-nexus.htm
#  Agent-based simulation of the forest-water-people nexus
# <ul><li>An interest in interdisciplinary work </li><li>An interest and preferably experience in agent-based modelling</li></ul>
# Requirements:
# - An interest in interdisciplinary work
# - An interest and preferably experience in agent-based modelling
# dr.ir. EN (Erika) Speelman
# https://www.wur.nl/en/persons/erika-speelman-1.htm
# Universitair hoofddocent
# Laboratory of Geo-information Science and Remote Sensing
# Erika Speelman
# 5
# https://www.wur.nl/en/article/msc-thsis-topic-ai-for-land-cover-change-monitoring.htm
#  AI for land cover change monitoring
# <ul><li></li><li>Affinity work with large scale remote sensing datasets</li></ul>
# Requirements:
# -
# - Affinity work with large scale remote sensing datasets
# dr. D (Dainius) Masiliunas
# https://www.wur.nl/en/persons/dainius-masiliunas.htm
# Docent
# Laboratory of Geo-information Science and Remote Sensing
# Dainius Masiliunas
# 3
# dr. NE (Nandika) Tsendbazar
# https://www.wur.nl/en/persons/nandika-tsendbazar.htm
# Assistant professor
# Laboratory of Geo-information Science and Remote Sensing
# Nandika Tsendbazar
# 5
# https://www.wur.nl/en/article/msc-thesis-topic-alternative-method-to-derive-clc2024.htm
#  Alternative method to derive CLC2024
# <ul><li><strong></strong>Knowledge/familiar with Dutch/European land monitoring</li><li>Change detection (real/technical changes)</li><li>GIS knowledge (QGIS/ArcGIS Pro)</li></ul>
# Requirements:
# - Knowledge/familiar with Dutch/European land monitoring
# - Change detection (real/technical changes)
# - GIS knowledge (QGIS/ArcGIS Pro)
# drs. GW (Gerard) Hazeu
# https://www.wur.nl/en/persons/gerard-hazeu.htm
# researcher Remote Sensing & GIS
# Applied Spatial Research
# Gerard Hazeu
# 1
# https://www.wur.nl/en/article/msc-thesis-topic-analysis-of-the-drivers-behind-three-decade-wetland-dynamics-in-the-netherlands.htm
#  Analysis of the drivers behind three-decade wetland dynamics in the Netherlands
# <ul><li>Genuine interest in this topic</li><li>Solid experience with Python or R (GRS-33806 Geo Scripting)</li></ul>
# Requirements:
# - Genuine interest in this topic
# - Solid experience with Python or R (GRS-33806 Geo Scripting)
# Y (Yang) Li
# https://www.wur.nl/en/persons/yang-li-3.htm
# PhD candidate
# Laboratory of Geo-information Science and Remote Sensing
# Yang Li
# 1
# dr. NE (Nandika) Tsendbazar
# https://www.wur.nl/en/persons/nandika-tsendbazar.htm
# https://www.wur.nl/en/article/msc-thesis-topic-assessing-correlation-between-land-use-change-and-cash-transfer-interventions.htm
#  Assessing correlation between land use change and cash transfer interventions
# <ul><li>Proficiency in remote sensing methodology</li></ul>
# Requirements:
# - Proficiency in remote sensing methodology
# prof.dr. R (Robert) Fletcher
# https://www.wur.nl/en/persons/robert-fletcher.htm
# Professor
# Sociology of Development and Change
# Robert Fletcher
# 1
# dr. NE (Nandika) Tsendbazar
# https://www.wur.nl/en/persons/nandika-tsendbazar.htm
# https://www.wur.nl/en/article/msc-thesis-topic-assessing-savannah-vegetation-structure-and-biomass-with-sentinel-1-radar-and-spaceborne-gedi-lidar-data-in-kruger-national-park.htm
#  Assessing savannah vegetation structure and biomass with Sentinel-1 radar and spaceborne GEDI lidar data in Kruger National Park
# <ul><li><strong></strong>Geo-scripting course (required)</li><li>Advanced Earth Observation (required)</li><li>GEE tutorials, such as (https://developers.google.com/earth-engine/tutorials/edu)</li></ul>
# Requirements:
# - Geo-scripting course (required)
# - Advanced Earth Observation (required)
# - GEE tutorials, such as (https://developers.google.com/earth-engine/tutorials/edu)
# dr. J (Johannes) Reiche
# https://www.wur.nl/en/persons/johannes-reiche.htm
# Associate Professor
# Laboratory of Geo-information Science and Remote Sensing
# Johannes Reiche
# 5
# M (Martín) Domínguez Durán MSc
# https://www.wur.nl/en/persons/martin-dominguez-duran-1.htm
# Onderzoeker
# Meteorology and Air Quality
# Martín Domínguez Durán
# 1
# https://www.wur.nl/en/article/msc-thesis-topic-augmented-reality-display-on-windshields-improving-the-spatial-awareness-of-autonomous-car-drivers.htm
#  Augmented reality display on windshields
# <ul><li>Interest in working with immersive technologies </li><li>Interest in human behaviors </li><li>Interest in empirical studies and evaluations </li><li>Experience with Python and spatial data analysis </li></ul>
# Max reqs: 4
# Requirements:
# - Interest in working with immersive technologies
# - Interest in human behaviors
# - Interest in empirical studies and evaluations
# - Experience with Python and spatial data analysis
# J (Jiayan) Zhao PhD
# https://www.wur.nl/en/persons/jiayan-zhao.htm
# https://www.wur.nl/en/article/msc-thesis-topic-automated-change-detection-and-classification-at-a-large-scale-in-bfast-lite.htm
#  Automated change detection and classification at a large scale in BFAST Lite
# <ul><li><strong></strong>Required: Geoscripting, Remote Sensing</li><li>Optional: Advanced Earth Observation</li></ul>
# Requirements:
# - Required: Geoscripting, Remote Sensing
# - Optional: Advanced Earth Observation
# dr. D (Dainius) Masiliunas
# https://www.wur.nl/en/persons/dainius-masiliunas.htm
# https://www.wur.nl/en/article/msc-thesis-topic-biochemical-and-biophysical-crop-trait-estimation-through-functional-structural-plant-and-radiative-transfer-modelling.htm
#  Biochemical and biophysical crop trait estimation through Functional-Structural Plant and Radiative Transfer Modelling
# <ul><li>Required: GeoScripting, Remote Sensing, Advance Earth Observation</li><li>Optional: Spatial Modelling and Statistics, Deep Learning</li></ul>
# Requirements:
# - Required: GeoScripting, Remote Sensing, Advance Earth Observation
# - Optional: Spatial Modelling and Statistics, Deep Learning
# dr. CL (Carlos) Camino Gonzalez
# https://www.wur.nl/en/persons/carlos-camino-gonzalez.htm
# Universitair docent
# Laboratory of Geo-information Science and Remote Sensing
# Carlos Camino Gonzalez
# 5
# dr. A (Alejandro) Morales Sierra
# https://www.wur.nl/en/persons/alejandro-morales-sierra-1.htm
# Lecturer
# Centre for Crop Systems Analysis
# Alejandro Morales Sierra
# 1
# dr. F (Francisco) Pinto Espinosa
# https://www.wur.nl/en/persons/francisco-pinto-espinosa.htm
# Assistant professor
# Centre for Crop Systems Analysis
# Francisco Pinto Espinosa
# 1
# https://www.wur.nl/en/article/msc-thesis-topic-biochemical-trait-retrieval-and-photosynthesis-dynamics-impacts-on-sun-induced-fluorescence-sif-from-ground-to-airborne-and-satellite-platforms..htm
#  Biochemical trait retrieval and photosynthesis dynamics
# <ul><li>Required: Geoscripting, Remote Sensing, Advance Earth Observation</li><li>Optional: Spatial Modelling and Statistics, Deep Learning</li></ul>
# Requirements:
# - Required: Geoscripting, Remote Sensing, Advance Earth Observation
# - Optional: Spatial Modelling and Statistics, Deep Learning
# dr. CL (Carlos) Camino Gonzalez
# https://www.wur.nl/en/persons/carlos-camino-gonzalez.htm
# dr. D (Dainius) Masiliunas
# https://www.wur.nl/en/persons/dainius-masiliunas.htm
# prof.dr.ir. L (Lammert) Kooistra
# https://www.wur.nl/en/persons/lammert-kooistra.htm
# Personal Professor Remote Sensing
# Laboratory of Geo-information Science and Remote Sensing
# Lammert Kooistra
# 5
# https://www.wur.nl/en/article/msc-thesis-topic-can-we-detect-small-temporal-differences-in-springfall-phenology-using-high-spatial-and-temporal-resolution-remote-sensing-data.htm
#  Can we detect small temporal differences in spring/fall phenology using high spatial and temporal resolution remote sensing data?
# <ul><li>Affinity with forest ecology </li><li>Followed the Advanced Earth Observation course (GRS32306), since drone data processing will be part of the methodology</li></ul>
# Requirements:
# - Affinity with forest ecology
# - Followed the Advanced Earth Observation course (GRS32306), since drone data processing will be part of the methodology
# dr. HM (Harm) Bartholomeus
# https://www.wur.nl/en/persons/harm-bartholomeus.htm
# Universitair docent
# Laboratory of Geo-information Science and Remote Sensing
# Harm Bartholomeus
# 5
# dr.ir. P (Paul) Copini
# https://www.wur.nl/en/persons/paul-copini-1.htm
# WR Onderzoeker
# Sustainable forest ecosystems
# Paul Copini
# 1
# NE (Niamh) Kelly
# https://www.wur.nl/en/persons/niamh-kelly-1.htm
# Onderzoeker
# Sustainable forest ecosystems
# Niamh Kelly
# 1
# https://www.wur.nl/en/article/msc-thesis-topic-cashew-mapping-across-continents-with-location-information.htm
#  Cashew Mapping across Continents with Location Information
# <ul><li>Experience with Pytorch, Google Earth Engine (required).</li><li>Attended the Deep Learning &amp; Remote Sensing courses (required).</li><li>Attended the Advanced Remote Sensing course (optional).</li></ul>
# Requirements:
# - Experience with Pytorch, Google Earth Engine (required).
# - Attended the Deep Learning & Remote Sensing courses (required).
# - Attended the Advanced Remote Sensing course (optional).
# RN (Robert) Masolele MSc
# https://www.wur.nl/en/persons/robert-masolele.htm
# Onderzoeker
# Laboratory of Geo-information Science and Remote Sensing
# Robert Masolele
# 2
# dr. MC (Marc) Russwurm
# https://www.wur.nl/en/persons/marc-russwurm.htm
# Assistant Professor
# Laboratory of Geo-information Science and Remote Sensing
# Marc Russwurm
# 5
# https://www.wur.nl/en/article/msc-thesis-topic-classifying-deforestation-drivers-in-europe-using-sentinel-satellites-and-ai.htm
#  Classifying deforestation drivers in Europe using Sentinel satellites and AI
# <ul><li>Geo-scripting course </li><li>(Advanced Earth Observation)</li><li>Machine learning</li><li>Deep learning</li></ul>
# Requirements:
# - Geo-scripting course
# - (Advanced Earth Observation)
# - Machine learning
# - Deep learning
# LE (Laura) Cué la Rosa
# https://www.wur.nl/en/persons/laura-cue-la-rosa.htm
# Onderzoeker
# Laboratory of Geo-information Science and Remote Sensing
# Laura Cué la Rosa
# 2
# dr. J (Johannes) Reiche
# https://www.wur.nl/en/persons/johannes-reiche.htm
# prof.dr. PA (Pieter) Zuidema
# https://www.wur.nl/en/persons/pieter-zuidema.htm
# Professor
# Forest Ecology and Forest Management
# Pieter Zuidema
# 1
# https://www.wur.nl/en/article/msc-thesis-topic-climate-land-use-change-and-biodiversity-the-paleoenvironmental-history-of-the-atlas-mountains.htm
#  Climate, Land-Use Change, and Biodiversity
# <ul><li>Good GIS background. </li><li>Geoscripting. </li><li>Affinity with history and historical GIS data. </li><li>Interest in historical GIS analysis. </li></ul>
# Requirements:
# - Good GIS background.
# - Geoscripting.
# - Affinity with history and historical GIS data.
# - Interest in historical GIS analysis.
# prof.dr. KM (Kirsten) de Beurs
# https://www.wur.nl/en/persons/kirsten-de-beurs-1.htm
# Professor/Chair
# Laboratory of Geo-information Science and Remote Sensing
# Kirsten de Beurs
# 5
# dr. JAJ (Jasper) Eikelboom
# https://www.wur.nl/en/persons/jasper-eikelboom.htm
# Docent
# Externe medewerker
# Laboratory of Geo-information Science and Remote Sensing
# Jasper Eikelboom
# 2
# https://www.wur.nl/en/article/msc-thesis-topic-commodity-crops-recognition-in-satellite-images-using-fourier-transform-a-new-look-at-signal-to-frequency-domain-for-detecting-commodity-crops..htm
#  Commodity crops recognition in satellite images using Fourier transform
# <ul><li><strong></strong>Mathematics</li><li>Advanced Earth Observation course</li><li>Machine learning course</li><li>Geo-scripting course (Good knowledge in scripting is an asset; e.g. python, Google Earth Engine, and java script) </li></ul>
# Requirements:
# - Mathematics
# - Advanced Earth Observation course
# - Machine learning course
# - Geo-scripting course (Good knowledge in scripting is an asset; e.g. python, Google Earth Engine, and java script)
# RN (Robert) Masolele MSc
# https://www.wur.nl/en/persons/robert-masolele.htm
# https://www.wur.nl/en/article/msc-thesis-topic-comparing-spaceborne-lidar-data-with-holdriges-forest-plots.htm
#  Comparing spaceborne LiDAR data with Holdrige’s forest plots
# <ul><li><strong></strong>At least Intro to Remote Sensing</li><li>Geoscripting</li><li>Affinity with the processing of satellite image time series</li><li>Affinity with spaceborn LiDAR data.</li></ul>
# Requirements:
# - At least Intro to Remote Sensing
# - Geoscripting
# - Affinity with the processing of satellite image time series
# - Affinity with spaceborn LiDAR data.
# prof.dr. KM (Kirsten) de Beurs
# https://www.wur.nl/en/persons/kirsten-de-beurs-1.htm
# https://www.wur.nl/en/article/msc-thesis-topic-comparison-of-land-cover-change-detection-methods-at-a-global-scale.htm
#  Comparison of land cover change detection methods at a global scale
# <ul><li>Geo Scripting </li><li>Affinity work with large scale remote sensing datasets <strong></strong></li></ul>
# Requirements:
# - Geo Scripting
# - Affinity work with large scale remote sensing datasets
# dr. D (Dainius) Masiliunas
# https://www.wur.nl/en/persons/dainius-masiliunas.htm
# dr. NE (Nandika) Tsendbazar
# https://www.wur.nl/en/persons/nandika-tsendbazar.htm
# https://www.wur.nl/en/article/msc-thesis-topic-complete-communities.htm
#  Complete Communities
# <ul><li>GIS</li><li>Self-motivated and interested in making this topic their own</li></ul>
# Requirements:
# - GIS
# - Self-motivated and interested in making this topic their own
# dr. JM (Jess) Wreyford
# https://www.wur.nl/en/persons/jess-wreyford.htm
# Docent
# Laboratory of Geo-information Science and Remote Sensing
# Jess Wreyford
# 3
# https://www.wur.nl/en/article/msc-thesis-topic-coverage-path-planning-for-autonomous-field-operations-1.htm
#  Coverage path planning for autonomous field operations
# <ul><li><strong></strong>Strong analytical skills</li><li>Knowledge of Python scripting is a must</li><li>Preferably some agronomic knowledge</li></ul>
# Requirements:
# - Strong analytical skills
# - Knowledge of Python scripting is a must
# - Preferably some agronomic knowledge
# prof.dr.ir. S (Sytze) de Bruin
# https://www.wur.nl/en/persons/sytze-de-bruin-1.htm
# associate professor
# Laboratory of Geo-information Science and Remote Sensing
# Sytze de Bruin
# 5
# G (Gonzalo) Mier Munoz MSc
# https://www.wur.nl/en/persons/gonzalo-mier-munoz.htm
# Promovendus
# Laboratory of Geo-information Science and Remote Sensing
# Gonzalo Mier Munoz
# 1
# https://www.wur.nl/en/article/msc-thesis-topic-data-driven-utility-route-planner-maps4cables-1.htm
#  Data Driven Utility Route Planner
# <ul><li>Dutch proficiency is preferred as much documentation is in Dutch</li><li>Experience with Python</li><li>If the reinforcement option is chosen: Deep Learning (GRS34806 or similar) </li><li>If opting for a graph-based solution: Interest in expanding existing basic knowledge on Graph Theory</li></ul>
# Requirements:
# - Dutch proficiency is preferred as much documentation is in Dutch
# - Experience with Python
# - If the reinforcement option is chosen: Deep Learning (GRS34806 or similar)
# - If opting for a graph-based solution: Interest in expanding existing basic knowledge on Graph Theory
# prof.dr.ir. S (Sytze) de Bruin
# https://www.wur.nl/en/persons/sytze-de-bruin-1.htm
# JPJ (Jelmar) Versleijen MSc
# https://www.wur.nl/en/persons/jelmar-versleijen.htm
# Externe medewerker
# Promovendus
# Laboratory of Geo-information Science and Remote Sensing
# Jelmar Versleijen
# 1
# https://www.wur.nl/en/article/msc-thesis-topic-data-fusion-of-satellite-and-weather-station-datafor-modelling-urban-heat-stress-mitigation-by-green-infrastructure.htm
#  Data Fusion of Satellite and Weather Station Datafor Modelling Urban Heat Stress Mitigation by Green Infrastructure
# <ul><li>Are interested in the MODIS, Landsat or Sentinel data </li><li>Basic programming (Python/R for data analysis) is better. </li></ul>
# Requirements:
# - Are interested in the MODIS, Landsat or Sentinel data
# - Basic programming (Python/R for data analysis) is better.
# dr. L (Lixia) Chu
# https://www.wur.nl/en/persons/lixia-chu.htm
# Docent
# Environmental Technology
# Lixia Chu
# 1
# dr. M (Maryam) Ghodsvali
# https://www.wur.nl/en/persons/maryam-ghodsvali.htm
# Universitair docent
# Laboratory of Geo-information Science and Remote Sensing
# Maryam Ghodsvali
# 5
# https://www.wur.nl/en/article/msc-thesis-topic-embed-odtp-digital-twins-anywhere-on-earth-with-anywherexr.htm
#  Embed ODTP digital twins anywhere on Earth with AnywhereXR
# <p>This topic is open to multiple students. Specific topics that students select will each have additional requirements that can be discussed on a case-by-case basis. The following requirements apply to all topics:</p>
# Requirements:
# dr. JU (Jascha) Grübel
# https://www.wur.nl/en/persons/jascha-grubel.htm
# Assistant Professor for Data Science Systems
# Laboratory of Geo-information Science and Remote Sensing
# Jascha Grübel
# 5
# https://www.wur.nl/en/article/msc-thesis-topic-deforestation-prediction-with-spatio-temporal-deep-learning-models.htm
#  Deforestation Prediction with Spatio-Temporal Deep Learning Models
# <ul><li><strong></strong>Geo-scripting course</li><li>Advanced Earth Observation</li><li>Machine Learning</li></ul>
# Requirements:
# - Geo-scripting course
# - Advanced Earth Observation
# - Machine Learning
# LE (Laura) Cué la Rosa
# https://www.wur.nl/en/persons/laura-cue-la-rosa.htm
# https://www.wur.nl/en/article/msc-thesis-topic-detecting-reindeer-carrion-in-the-arctic-tundra-of-svalbard.htm
#  Detecting reindeer carrion in the Arctic tundra of Svalbard
# <ul><li>This year not fieldwork is planned for this thesis topic. The research will focus on the evaluation of high-resolution image sources (drone or satellite) for detection of the carcasses. Datasets of previous years and newly acquired satellite imagery will be used starting point. </li><li>Experience in machine learning and deep learning for object detection. </li></ul>
# Requirements:
# - This year not fieldwork is planned for this thesis topic. The research will focus on the evaluation of high-resolution image sources (drone or satellite) for detection of the carcasses. Datasets of previous years and newly acquired satellite imagery will be used starting point.
# - Experience in machine learning and deep learning for object detection.
# prof.dr.ir. L (Lammert) Kooistra
# https://www.wur.nl/en/persons/lammert-kooistra.htm
# https://www.wur.nl/en/article/msc-thesis-topic-domain-adaptation-for-mapping-commodity-crops-in-africa.htm
#  Domain adaptation for mapping commodity crops in Africa
# <ul><li>Advanced Earth Observation course </li><li>Machine learning course </li><li>Geo-scripting course (Good knowledge in scripting is an asset; e.g. python, Google Earth Engine, and java script)  </li></ul>
# Requirements:
# - Advanced Earth Observation course
# - Machine learning course
# - Geo-scripting course (Good knowledge in scripting is an asset; e.g. python, Google Earth Engine, and java script)
# RN (Robert) Masolele MSc
# https://www.wur.nl/en/persons/robert-masolele.htm
# LE (Laura) Cué la Rosa
# https://www.wur.nl/en/persons/laura-cue-la-rosa.htm
# https://www.wur.nl/en/article/msc-thesis-topic-drought-induced-structural-changes-in-chilean-mediterranean-evergreen-forest.htm
#  Drought-induced structural changes in Chilean mediterranean evergreen forest
# <ul><li>Geo-scripting (R of Python)</li><li>Advanced Earth Observation</li></ul>
# Requirements:
# - Geo-scripting (R of Python)
# - Advanced Earth Observation
# J (José) Lastra Muñoz
# https://www.wur.nl/en/persons/jose-lastra-munoz.htm
# Externe medewerker
# Promovendus
# Laboratory of Geo-information Science and Remote Sensing
# José Lastra Muñoz
# 1
# https://www.wur.nl/en/article/msc-thesis-topic-dutch-forest-monitor-ahn-based-forest-change-detection-in-the-netherlands.htm
#  Dutch Forest Monitor
# <ul><li>Due to the relatively large file sizes (point clouds) the methods for this thesis research must be implemented in a scripting language like Python, most likely R. Therefor basic scripting skills (e.g. python or R) are required, but especially the curiosity and willingness to learn/invest more in (geo)scripting skills. </li><li>Enthusiast of lidar in combination with a passion for the green nature and forests.</li></ul>
# Requirements:
# - Due to the relatively large file sizes (point clouds) the methods for this thesis research must be implemented in a scripting language like Python, most likely R. Therefor basic scripting skills (e.g. python or R) are required, but especially the curiosity and willingness to learn/invest more in (geo)scripting skills.
# - Enthusiast of lidar in combination with a passion for the green nature and forests.
# LC (Corné) Vreugdenhil MSc
# https://www.wur.nl/en/persons/corne-vreugdenhil-2.htm
# Docent
# Laboratory of Geo-information Science and Remote Sensing
# Corné Vreugdenhil
# 3
# https://www.wur.nl/en/article/msc-thesis-topic-early-detection-of-bark-beetle-infestation-using-sentinel-2-thermal-sensors-and-biophysical-models.htm
#  Early Detection of Bark Beetle Infestation Using Sentinel-2, Thermal Sensors, and Biophysical Models
# <ul><li>Required: Geoscripting, Remote Sensing, Advance Earth Observation</li><li>Optional: Spatial Modelling and Statistics, Deep Learning</li></ul>
# Requirements:
# - Required: Geoscripting, Remote Sensing, Advance Earth Observation
# - Optional: Spatial Modelling and Statistics, Deep Learning
# dr. CL (Carlos) Camino Gonzalez
# https://www.wur.nl/en/persons/carlos-camino-gonzalez.htm
# https://www.wur.nl/en/article/msc-thesis-topic-estimating-foregone-forest-loss-around-a-redd-project.htm
#  Estimating Foregone Forest Loss around a REDD project
# <ul><li><strong></strong>Geo-scripting course</li><li>Remote Sensing</li><li>Advanced Earth Observation</li></ul>
# Requirements:
# - Geo-scripting course
# - Remote Sensing
# - Advanced Earth Observation
# dr.ir. MJ (Maarten) Voors
# https://www.wur.nl/en/persons/maarten-voors.htm
# Associate Professor
# Development Economics
# Maarten Voors
# 1
# https://www.wur.nl/en/article/msc-thesis-topic-ethics-in-geo-infromation-science.-building-a-framework-for-considering-the-issues-of-ethical-and-moral-aspects-of-using-location-data.htm
#  Ethics in Geo-infromation Science. Building a framework for considering the issues of ethical and moral aspects of using location data
# No requirements!
# dr.ir. L (Lukasz) Grus
# https://www.wur.nl/en/persons/lukasz-grus.htm
# Medewerker onderwijsontwikkeling
# Opleidingsmanager
# Assistant Professor Geo-information Science; Education Coordinator Data Science
# Wageningen Data Competence Center
# Lukasz Grus
# 1
# https://www.wur.nl/en/article/msc-thesis-topic-evaluate-agrodatacube-usability-for-agrofood-application-use-cases.htm
#  Evaluate AgroDataCube usability for Agro/Food application use cases
# No requirements!
# dr.ir. L (Lukasz) Grus
# https://www.wur.nl/en/persons/lukasz-grus.htm
# https://www.wur.nl/en/article/msc-thesis-topic-using-sentinel-2-for-monitoring-grazing-activities-in-the-netherlands.htm
#  Using Sentinel-2 for monitoring grazing activities in the Netherlands
# <ul><li>Remote sensing (GRS-20306) </li><li>Advanced Earth Observation (GRS-32306)  </li></ul>
# Requirements:
# - Remote sensing (GRS-20306)
# - Advanced Earth Observation (GRS-32306)
# ir. GJ (Gerbert) Roerink
# https://www.wur.nl/en/persons/gerbert-roerink.htm
# WR Onderzoeker
# Earth Observation and Environmental Informatics
# Gerbert Roerink
# 1
# https://www.wur.nl/en/article/msc-thesis-topic-ethics-in-gis.htm
#  Ethics in GIS
# <ul><li>No specific requirements, but an interest in ethical dilemma’s and knowledge of interview techniques and analysis is a plus.</li></ul>
# Requirements:
# - No specific requirements, but an interest in ethical dilemma’s and knowledge of interview techniques and analysis is a plus.
# prof.dr.ir. AK (Arnold) Bregt
# https://www.wur.nl/en/persons/arnold-bregt-1.htm
# Dean  of Education
# Professor
# Education & Student Affairs
# Arnold Bregt
# 1
# https://www.wur.nl/en/article/msc-thesis-topic-explainable-artificial-intelligence-in-mobility-prediction.htm
#  Explainable Artificial Intelligence in Mobility
# Prediction
# <ul><li><strong></strong>Good python knowledge (required)</li><li>Machine learning and deep learning basics (required)</li><li>Causal inference (optional)</li><li>Digital Twin background (optional)</li><li>Transport &amp; Mobility research interest (optional)<br/></li></ul>
# Max reqs: 5
# Requirements:
# - Good python knowledge (required)
# - Machine learning and deep learning basics (required)
# - Causal inference (optional)
# - Digital Twin background (optional)
# - Transport & Mobility research interest (optional)
# dr. JU (Jascha) Grübel
# https://www.wur.nl/en/persons/jascha-grubel.htm
# https://www.wur.nl/en/article/msc-thesis-topic-explainable-land-cover-maps-deriving-classes-fromland-surface-traits.htm
#  Explainable land cover maps
# <ul><li>Required: Geoscripting, Remote Sensing</li><li>Optional: Machine learning, Advanced Earth Observation</li></ul>
# Requirements:
# - Required: Geoscripting, Remote Sensing
# - Optional: Machine learning, Advanced Earth Observation
# dr. D (Dainius) Masiliunas
# https://www.wur.nl/en/persons/dainius-masiliunas.htm
# dr. NE (Nandika) Tsendbazar
# https://www.wur.nl/en/persons/nandika-tsendbazar.htm
# dr. CL (Carlos) Camino Gonzalez
# https://www.wur.nl/en/persons/carlos-camino-gonzalez.htm
# https://www.wur.nl/en/article/msc-thesis-topic-exploring-agro-ecological-intensification-in-topical-agricultural-landscapes-through-agent-based-modelling-the-case-of-semi-arid-burkina-faso.htm
#  Exploring agro-ecological intensification in topical agricultural landscapes through agent-based modelling
# <ul><li>Interest and some experience in agent based modelling (in particular Netlogo) </li><li>Interest in behavioural decision-making theories </li></ul>
# Requirements:
# - Interest and some experience in agent based modelling (in particular Netlogo)
# - Interest in behavioural decision-making theories
# dr.ir. EN (Erika) Speelman
# https://www.wur.nl/en/persons/erika-speelman-1.htm
# https://www.wur.nl/en/article/msc-thesis-topic-exploring-land-cover-degradation-and-recovery-using-fractions.htm
#  Exploring land cover degradation and recovery using fractions
# <ul><li><strong></strong>Required: Geoscripting, Remote Sensing</li><li>Optional: Advanced Earth Observation</li></ul>
# Requirements:
# - Required: Geoscripting, Remote Sensing
# - Optional: Advanced Earth Observation
# dr. D (Dainius) Masiliunas
# https://www.wur.nl/en/persons/dainius-masiliunas.htm
# dr. NE (Nandika) Tsendbazar
# https://www.wur.nl/en/persons/nandika-tsendbazar.htm
# https://www.wur.nl/en/article/msc-thesis-topic-exploring-novel-quinoa-variants-high-throughput-phenotyping-data-analysis-under-drought-stress.htm
#  Exploring novel quinoa variants
# <ul><li>Experience in R and Python </li><li>Basic knowledge on image analysis </li></ul>
# Requirements:
# - Experience in R and Python
# - Basic knowledge on image analysis
# M (Mieke) van Vlaardingen MSc
# https://www.wur.nl/en/persons/mieke-van-vlaardingen-1.htm
# Promovendus
# Promovendus
# Plant Breeding
# Mieke van Vlaardingen
# 1
# prof.dr.ir. L (Lammert) Kooistra
# https://www.wur.nl/en/persons/lammert-kooistra.htm
# https://www.wur.nl/en/article/msc-thesis-topic-exploring-resilience-in-socio-ecological-systems.htm
#  Exploring resilience in Socio Ecological Systems
# <ul><li>Affinity with ABM, e.g. in Netlogo, GAMA, Python, or a similar software language </li><li>Knowledge of Python or R for data analysis and the implementation of the analysis method </li></ul>
# Requirements:
# - Affinity with ABM, e.g. in Netlogo, GAMA, Python, or a similar software language
# - Knowledge of Python or R for data analysis and the implementation of the analysis method
# dr.ir. A (Arend) Ligtenberg
# https://www.wur.nl/en/persons/arend-ligtenberg.htm
# dr. GAK (George) van Voorn
# https://www.wur.nl/en/persons/george-van-voorn.htm
# Associate Professor Applied Modelling & Machine Learning
# Mathematical and Statistical Methods
# Biometris
# 1
# https://www.wur.nl/en/article/msc-thesis-topic-exploring-system-dynamics-as-a-result-of-human-decision-making-the-case-of-the-agrodiversity-v.2-agent-based-model.htm
#  Exploring system dynamics as a result of human decision-making; the case of the Agrodiversity v.2 agent-based model
# <ul><li>Interest and some experience in agent based modelling </li><li>Interest in behavioural decision-making theories</li></ul>
# Requirements:
# - Interest and some experience in agent based modelling
# - Interest in behavioural decision-making theories
# dr.ir. EN (Erika) Speelman
# https://www.wur.nl/en/persons/erika-speelman-1.htm
# https://www.wur.nl/en/article/msc-thesis-topic-exploring-the-impact-of-land-use-dynamics-and-eutrophication-on-aquatic-vegetation-in-lake-tana-and-abaya-chamo-lake-basins-a-three-decade-study..htm
#  Exploring the impact of land-use dynamics and eutrophication on aquatic vegetation in Lake Tana and Abaya-Chamo lake basins
# <ul><li>Advanced Earth Observation</li><li>Deep learning </li><li>Geo-scripting </li></ul>
# Requirements:
# - Advanced Earth Observation
# - Deep learning
# - Geo-scripting
# AB (Alemu) Debay
# https://www.wur.nl/en/persons/alemu-debay.htm
# Promovendus
# Promovendus
# Laboratory of Geo-information Science and Remote Sensing
# Alemu Debay
# 1
# dr. NE (Nandika) Tsendbazar
# https://www.wur.nl/en/persons/nandika-tsendbazar.htm
# https://www.wur.nl/en/article/msc-thesis-topic-eye-tracking-in-immersive-virtual-environments-collection-validation-and-analysis.htm
#  Eye-tracking in immersive virtual environments
# <ul><li>Experience with Python and spatial data analysis </li><li>Interest in working with immersive technologies </li><li>Interest in human behaviors </li><li>Interest in empirical studies and evaluations </li></ul>
# Requirements:
# - Experience with Python and spatial data analysis
# - Interest in working with immersive technologies
# - Interest in human behaviors
# - Interest in empirical studies and evaluations
# J (Jiayan) Zhao PhD
# https://www.wur.nl/en/persons/jiayan-zhao.htm
# https://www.wur.nl/en/article/msc-thesis-topic-feature-space-coverage-and-uncertainty-in-spatial-biomass-prediction.htm
#  Feature Space Coverage and Uncertainty in Spatial Biomass Prediction
# <ul><li>Spatial Modelling and Statistics (GRS30306)</li><li>Interest in machine learning</li></ul>
# Requirements:
# - Spatial Modelling and Statistics (GRS30306)
# - Interest in machine learning
# prof.dr.ir. S (Sytze) de Bruin
# https://www.wur.nl/en/persons/sytze-de-bruin-1.htm
# https://www.wur.nl/en/article/msc-thesis-topic-few-shot-learning-across-remote-sensing-problems.htm
#  Few-Shot Learning across Remote Sensing Problems
# <ul><li>Deep Learning course (required)</li><li>Remote Sensing (optional)</li></ul>
# Requirements:
# - Deep Learning course (required)
# - Remote Sensing (optional)
# dr. MC (Marc) Russwurm
# https://www.wur.nl/en/persons/marc-russwurm.htm
# https://www.wur.nl/en/article/msc-thesis-topic-few-shot-learning-for-fine-wetland-classification-a-meta-learning-approach.htm
#  Few-shot learning for fine wetland classification
# <ul><li>Genuine interest in this topic</li><li>GRS-34809 Deep Learning in Data Science</li></ul>
# Requirements:
# - Genuine interest in this topic
# - GRS-34809 Deep Learning in Data Science
# Y (Yang) Li
# https://www.wur.nl/en/persons/yang-li-3.htm
# prof.dr.ir. L (Lammert) Kooistra
# https://www.wur.nl/en/persons/lammert-kooistra.htm
# https://www.wur.nl/en/article/msc-thesis-topic-forest-growth-quantified-with-micrometeorological-and-remote-sensing-methods.htm
#  Forest Growth quantified with micrometeorological and remote sensing methods
# <ul><li><strong></strong>Scripting skills (e.g. R, Python) are a preference</li><li>Basic knowledge of forestry</li><li>Completion GRS32306 Advanced Earth Observation</li></ul>
# Requirements:
# - Scripting skills (e.g. R, Python) are a preference
# - Basic knowledge of forestry
# - Completion GRS32306 Advanced Earth Observation
# dr. HM (Harm) Bartholomeus
# https://www.wur.nl/en/persons/harm-bartholomeus.htm
# dr.ir. MK (Michiel) van der Molen
# https://www.wur.nl/en/persons/michiel-van-der-molen.htm
# University Lecturer
# Meteorology and Air Quality
# Michiel van der Molen
# 1
# https://www.wur.nl/en/article/msc-thsis-topic-forest-ecosystem-monitoring-integrating-biophysical-approaches-high-resolution-hyperspectral-imaging-and-eddy-covariance-flux-towers..htm
#  Forest ecosystem monitoring
# No requirements!
# dr. CL (Carlos) Camino Gonzalez
# https://www.wur.nl/en/persons/carlos-camino-gonzalez.htm
# prof.dr.ir. L (Lammert) Kooistra
# https://www.wur.nl/en/persons/lammert-kooistra.htm
# dr.ir. MK (Michiel) van der Molen
# https://www.wur.nl/en/persons/michiel-van-der-molen.htm
# https://www.wur.nl/en/article/msc-thesis-topic-from-croplands-to-urban-land-cover-change-in-the-netherlands.htm
#  From croplands to urban
# <ul><li>At least Intro to Remote Sensing</li><li>Experience or interest in the processing of raster datasets</li><li>Geoscripting</li></ul>
# Requirements:
# - At least Intro to Remote Sensing
# - Experience or interest in the processing of raster datasets
# - Geoscripting
# prof.dr. KM (Kirsten) de Beurs
# https://www.wur.nl/en/persons/kirsten-de-beurs-1.htm
# prof.dr. MM (Martha) Bakker
# https://www.wur.nl/en/persons/martha-bakker.htm
# Professor/Chairholder Land Use Planning Group
# Landscape Architecture and Spatial Planning
# Martha Bakker
# 1
# https://www.wur.nl/en/article/msc-thesis-topic-from-pot-to-plot-correlating-high-throughput-phenotyping-data-from-a-greenhouse-experiment-to-field-performance.htm
#  From pot-to-plot
# <ul><li>Experience in R and Python</li><li>Basic knowledge on image analysis</li></ul>
# Requirements:
# - Experience in R and Python
# - Basic knowledge on image analysis
# M (Mieke) van Vlaardingen MSc
# https://www.wur.nl/en/persons/mieke-van-vlaardingen-1.htm
# prof.dr.ir. L (Lammert) Kooistra
# https://www.wur.nl/en/persons/lammert-kooistra.htm
# https://www.wur.nl/en/article/msc-thesis-topic-gaming-for-active-participation-in-local-landscape-planning.htm
#  Gaming for active participation in (local) landscape planning
# <ul><li>Interest in participatory research</li><li>A link or connections to a relevant case study or project</li></ul>
# Requirements:
# - Interest in participatory research
# - A link or connections to a relevant case study or project
# dr.ir. EN (Erika) Speelman
# https://www.wur.nl/en/persons/erika-speelman-1.htm
# https://www.wur.nl/en/article/msc-thesis-topic-garbage-in-garbage-out-understanding-the-impact-of-training-datasets-on-remote-sensing-based-monitoring.htm
#  Garbage in garbage out? understanding the impact of training datasets on remote sensing based monitoring
# <ul><li>Advanced remote sensing </li><li>Geoscripting</li></ul>
# Requirements:
# - Advanced remote sensing
# - Geoscripting
# dr. NE (Nandika) Tsendbazar
# https://www.wur.nl/en/persons/nandika-tsendbazar.htm
# prof.dr.ir. S (Sytze) de Bruin
# https://www.wur.nl/en/persons/sytze-de-bruin-1.htm
# https://www.wur.nl/en/article/msc-thesis-topic-global-earth-observation-products-are-they-useful-for-countries.htm
#  Global earth observation products
# <ul><li>Geotools </li><li>Interests to work in Google Earth Engine </li></ul>
# Requirements:
# - Geotools
# - Interests to work in Google Earth Engine
# dr. NE (Nandika) Tsendbazar
# https://www.wur.nl/en/persons/nandika-tsendbazar.htm
# https://www.wur.nl/en/article/msc-thesis-topic-grassland-bird-fire-regime-associations-on-the-kibara-plateau-dr-congo.htm
#  Grassland Bird Fire Regime Associations on the Kibara Plateau, DR Congo
# <ul><li>Programming experience with R</li><li>Optional: Passion for or knowledge around ornithology</li></ul>
# Requirements:
# - Programming experience with R
# - Optional: Passion for or knowledge around ornithology
# M (Manuel) Weber
# https://www.wur.nl/en/persons/manuel-weber.htm
# Externe medewerker
# Promovendus
# Laboratory of Geo-information Science and Remote Sensing
# Manuel Weber
# 1
# https://www.wur.nl/en/article/msc-thesis-topic-high-resolution-uav-imagery-for-fruit-counting-in-orchards-utilizing-deep-learning.htm
#  High-resolution UAV imagery for fruit counting in orchards utilizing deep learning
# No requirements!
# prof.dr.ir. L (Lammert) Kooistra
# https://www.wur.nl/en/persons/lammert-kooistra.htm
# https://www.wur.nl/en/article/msc-thesis-topic-how-does-density-matter-the-impact-of-sentinel-1-time-series-density-on-detecting-various-types-of-tropical-forest-disturbances..htm
#  How Does Density Matter? The Impact of Sentinel-1 Time Series Density on Detecting Various Types of Tropical Forest Disturbances.
# <br/>
# Requirements:
# dr. J (Johannes) Balling MSc
# https://www.wur.nl/en/persons/johannes-balling.htm
# Onderzoeker
# Laboratory of Geo-information Science and Remote Sensing
# Johannes Balling
# 2
# dr. D (Dainius) Masiliunas
# https://www.wur.nl/en/persons/dainius-masiliunas.htm
# https://www.wur.nl/en/article/msc-thesis-topic-how-well-can-we-update-land-cover-fraction-maps.htm
#  How well can we update land cover fraction maps?
# <ul><li>Geoscripting</li></ul>
# Requirements:
# - Geoscripting
# dr. D (Dainius) Masiliunas
# https://www.wur.nl/en/persons/dainius-masiliunas.htm
# dr. NE (Nandika) Tsendbazar
# https://www.wur.nl/en/persons/nandika-tsendbazar.htm
# https://www.wur.nl/en/article/msc-thesis-topic-identification-of-candidate-locations-for-industrial-areas-in-oklahoma-city.htm
#  Identification of Candidate Locations for Industrial Areas in Oklahoma City
# <ul><li>Introduction to Geo-information Science</li><li>Geo-information Tools</li><li>Interest in socio-environmental research</li></ul>
# Requirements:
# - Introduction to Geo-information Science
# - Geo-information Tools
# - Interest in socio-environmental research
# dr. JAM (Jennifer) Koch
# https://www.wur.nl/en/persons/jennifer-koch.htm
# Universitair hoofddocent
# Laboratory of Geo-information Science and Remote Sensing
# Jennifer Koch
# 5
# https://www.wur.nl/en/article/msc-thesis-topic-identifying-potato-disease-in-uav-imagery-with-deep-learning.htm
#  Identifying potato disease in UAV imagery with deep learning
# <ul><li><strong></strong>Option to conduct fieldwork: needs discussion with supervisors.</li><li>Experience and/or interest in processing hyperspectral imagery.</li><li>Good knowledge in scripting, preferably using Python.</li></ul>
# Requirements:
# - Option to conduct fieldwork: needs discussion with supervisors.
# - Experience and/or interest in processing hyperspectral imagery.
# - Good knowledge in scripting, preferably using Python.
# T (Tianyi) Jia
# https://www.wur.nl/en/persons/tianyi-jia.htm
# Promovendus
# Laboratory of Geo-information Science and Remote Sensing
# Tianyi Jia
# 1
# prof.dr.ir. L (Lammert) Kooistra
# https://www.wur.nl/en/persons/lammert-kooistra.htm
# https://www.wur.nl/en/article/msc-thesis-topic-immersive-virtual-environments-based-on-open-geospatial-data-generation-improvement-evaluation-and-application.htm
#  Immersive virtual environments based on open geospatial data
# <ul><li>Interest in 3D &amp; immersive technologies </li><li>Interest in technical development or empirical evaluations </li></ul>
# Requirements:
# - Interest in 3D & immersive technologies
# - Interest in technical development or empirical evaluations
# J (Jiayan) Zhao PhD
# https://www.wur.nl/en/persons/jiayan-zhao.htm
# prof.dr. AKAJ (Alexander) Klippel
# https://www.wur.nl/en/persons/alexander-klippel.htm
# Personal Professor
# Cultural Geography
# Alexander Klippel
# 1
# https://www.wur.nl/en/article/grsthesis2014grus1.htm
#  Impact of open geodata
# No requirements!
# dr.ir. L (Lukasz) Grus
# https://www.wur.nl/en/persons/lukasz-grus.htm
# prof.dr.ir. AK (Arnold) Bregt
# https://www.wur.nl/en/persons/arnold-bregt-1.htm
# https://www.wur.nl/en/article/msc-thesis-topic-implicit-neural-representation-of-the-earth-gravity-field.htm
#  Implicit Neural Representation of the Earth Gravity Field
# <ul><li><strong></strong>recommended: deep learning course</li><li>recommended: interest in data representation </li><li>recommended: interest in math and Geodesy</li></ul>
# Requirements:
# - recommended: deep learning course
# - recommended: interest in data representation
# - recommended: interest in math and Geodesy
# dr. MC (Marc) Russwurm
# https://www.wur.nl/en/persons/marc-russwurm.htm
# https://www.wur.nl/en/article/msc-thesis-topic-improving-bird-species-distribution-and-abundance-models-by-integrating-uncertainty.htm
#  Improving Bird Species Distribution (and Abundance) Models By Integrating Uncertainty
# <ul><li>Passion for birds and open for a data-driven perspective on bird species distributions</li><li>Knowledge of R is desirable </li></ul>
# Requirements:
# - Passion for birds and open for a data-driven perspective on bird species distributions
# - Knowledge of R is desirable
# LC (Corné) Vreugdenhil MSc
# https://www.wur.nl/en/persons/corne-vreugdenhil-2.htm
# https://www.wur.nl/en/article/msc-thesis-topic-incorporating-uncertainty-in-spatial-decision-making.htm
#  Incorporating uncertainty in spatial decision making
# <ul><li>Having passed the ‘Spatial Modelling and Statistics’ course is desired because much of the required methodology has been covered in that course.</li></ul>
# Requirements:
# - Having passed the ‘Spatial Modelling and Statistics’ course is desired because much of the required methodology has been covered in that course.
# prof.dr.ir. GBM (Gerard) Heuvelink
# https://www.wur.nl/en/persons/gerard-heuvelink.htm
# Professor
# ISRIC
# World Soil Information
# 1
# prof.dr.ir. S (Sytze) de Bruin
# https://www.wur.nl/en/persons/sytze-de-bruin-1.htm
# https://www.wur.nl/en/article/msc-thesis-topic-incorporating-viewsheds-in-distance-samplingtechniques-to-estimate-wildlife-populations-in-the-kgalagadi-transfrontier-park.htm
#  Incorporating viewsheds in distance samplingtechniques to estimate wildlife populations in the Kgalagadi Transfrontier Park
# <ul><li>GIS and remote sensing knowledge, to classify vegetation and construct a DSM</li><li>Experience with statistics by having completed e.g. Advanced Statistics (MAT20306) or Ecological Methods (WEC31806)</li><li>Programming experience (R or Python)</li></ul>
# Requirements:
# - GIS and remote sensing knowledge, to classify vegetation and construct a DSM
# - Experience with statistics by having completed e.g. Advanced Statistics (MAT20306) or Ecological Methods (WEC31806)
# - Programming experience (R or Python)
# dr. JAJ (Jasper) Eikelboom
# https://www.wur.nl/en/persons/jasper-eikelboom.htm
# ir. AR (Aldo) Bergsma
# https://www.wur.nl/en/persons/aldo-bergsma.htm
# Lecturer
# Laboratory of Geo-information Science and Remote Sensing
# Aldo Bergsma
# 3
# https://www.wur.nl/en/article/msc-thesis-topic-individual-tree-detection-and-segmentation-with-terrestrial-lidar-point-clouds-of-tropical-forests.htm
#  Individual tree detection and segmentation with Terrestrial Lidar point clouds of tropical forests
# <ul><li>Scripting skills (e.g. R, Python, MatLab) are a preference </li><li>Basic knowledge of Cloudcompare software Completion </li><li>GRS-32306 Advanced Earth Observation </li></ul>
# Requirements:
# - Scripting skills (e.g. R, Python, MatLab) are a preference
# - Basic knowledge of Cloudcompare software Completion
# - GRS-32306 Advanced Earth Observation
# dr.ir. AI (Alvaro) Lau Sarmiento MSc
# https://www.wur.nl/en/persons/alvaro-lau-sarmiento-1.htm
# https://www.wur.nl/en/article/msc-thesis-topic-integrating-hyperspectral-and-lidar-data-for-tree-species-mapping-and-canopy-trait-validation-in-forest-ecosystems.htm
#  Integrating Hyperspectral and LiDAR Data for Tree Species Mapping and Canopy Trait Validation in Forest Ecosystems
# <em> </em>
# Requirements:
# dr. CL (Carlos) Camino Gonzalez
# https://www.wur.nl/en/persons/carlos-camino-gonzalez.htm
# dr. HM (Harm) Bartholomeus
# https://www.wur.nl/en/persons/harm-bartholomeus.htm
# https://www.wur.nl/en/article/msc-thesis-topic-integrating-prisma-hyperspectral-imagery-with-sentinel-2-time-series-for-estimating-gpp-using-biophysical-models-and-eddy-covariance-flux-tower-in-european-forest-ecosystems..htm
#  Integrating PRISMA hyperspectral imagery with Sentinel-2 time series for estimating GPP using Biophysical models  and eddy covariance flux tower in European forest ecosystems.
# <ul><li>Required: Geoscripting, Machine Learning, Remote Sensing, Advance Earth Observation</li><li>Optional: Spatial Modelling and Statistics, Deep Learning</li></ul>
# Requirements:
# - Required: Geoscripting, Machine Learning, Remote Sensing, Advance Earth Observation
# - Optional: Spatial Modelling and Statistics, Deep Learning
# dr. CL (Carlos) Camino Gonzalez
# https://www.wur.nl/en/persons/carlos-camino-gonzalez.htm
# https://www.wur.nl/en/article/msc-thesis-topic-inventory-stem-map-alignment-based-on-t-lidar-based-map.htm
#  Inventory stem map alignment based on T-LiDAR based map
# No requirements!
# dr.ir. AI (Alvaro) Lau Sarmiento MSc
# https://www.wur.nl/en/persons/alvaro-lau-sarmiento-1.htm
# https://www.wur.nl/en/article/msc-thesis-topic-interpreting-training-data-weights-in-random-forest-predictions.htm
#  Interpreting training data weights in random forest predictions
# <ul><li>Background in machine learning, scripting in R and digital soil mapping is advantageous but not required.</li></ul>
# Requirements:
# - Background in machine learning, scripting in R and digital soil mapping is advantageous but not required.
# prof.dr.ir. GBM (Gerard) Heuvelink
# https://www.wur.nl/en/persons/gerard-heuvelink.htm
# prof.dr.ir. S (Sytze) de Bruin
# https://www.wur.nl/en/persons/sytze-de-bruin-1.htm
# https://www.wur.nl/en/article/msc-thesis-topic-visualizing-crop-growth-in-a-digital-twin-combining-uav-data-and-a-crop-growth-models.htm
#  Visualizing crop growth in a Digital Twin
# No requirements!
# dr. JU (Jascha) Grübel
# https://www.wur.nl/en/persons/jascha-grubel.htm
# prof.dr.ir. L (Lammert) Kooistra
# https://www.wur.nl/en/persons/lammert-kooistra.htm
# https://www.wur.nl/en/article/msc-thesis-topic-land-surface-phenology-dynamics-in-chile-mediterranean-biodiversity-hotspot..htm
#  Land surface phenology dynamics in Chile Mediterranean biodiversity hotspot.
# <ul><li>Geo-scripting</li><li>Advanced Earth Observation</li></ul>
# Requirements:
# - Geo-scripting
# - Advanced Earth Observation
# J (José) Lastra Muñoz
# https://www.wur.nl/en/persons/jose-lastra-munoz.htm
# https://www.wur.nl/en/article/msc-thesis-topic-mapping-tourist-and-citizen-interests-in-st.eustatius-leveraging-geospatial-data-for-sustainable-development.htm
#  Mapping tourist and citizen interests in St.Eustatius
# No requirements!
# dr. PJFM (Peter) Verweij
# https://www.wur.nl/en/persons/peter-verweij.htm
# WR Onderzoeker
# Earth Observation and Environmental Informatics
# Peter Verweij
# 1
# dr. A (Anouk) Cormont
# https://www.wur.nl/en/persons/anouk-cormont-1.htm
# WR Onderzoeker
# Earth Observation and Environmental Informatics
# Anouk Cormont
# 1
# https://www.wur.nl/en/article/msc-thesis-topic-megaprojects-vs-nature-landscape-connectivity-in-the-yucatan-peninsula..htm
#  Megaprojects vs nature
# <ul><li>Student has followed GRS20806 Geotools </li></ul>
# Requirements:
# - Student has followed GRS20806 Geotools
# FA (Frida) Ruiz Mendoza MSc
# https://www.wur.nl/en/persons/frida-ruiz-mendoza.htm
# Docent
# Laboratory of Geo-information Science and Remote Sensing
# Frida Ruiz Mendoza
# 3
# ir. AR (Aldo) Bergsma
# https://www.wur.nl/en/persons/aldo-bergsma.htm
# https://www.wur.nl/en/article/msc-thesis-topic-modelling-environmental-dna-transport-in-north-sea-using-lagrangian-particle-tracking.htm
#  Modelling environmental DNA transport in North Sea using Lagrangian particle tracking
# ...
# - Required: experience in remote sensing data analysis (e.g. remote sensing software, spectral analysis, indices);
# - Optional: affinity with fieldwork (in and around rivers)
# - Optional: interest in (plastic) pollution
# dr.ir. THM (Tim) van Emmerik
# https://www.wur.nl/en/persons/tim-van-emmerik.htm
# dr. MC (Marc) Russwurm
# https://www.wur.nl/en/persons/marc-russwurm.htm
# https://www.wur.nl/en/article/msc-thesis-topic-studying-space-use-of-humpback-mahseer-in-thecauvery-river-basin-in-karnataka-india.htm
#  Studying space use of Humpback Mahseer in theCauvery river basin in Karnataka India
# <ul><li>Spatial temporal analysis for Earth and Environment </li><li>Geoscripting </li><li>Spatial modelling and statistics</li></ul>
# Requirements:
# - Spatial temporal analysis for Earth and Environment
# - Geoscripting
# - Spatial modelling and statistics
# AJ (Arno) Timmer MSc
# https://www.wur.nl/en/persons/arno-timmer-1.htm
# Docent
# Laboratory of Geo-information Science and Remote Sensing
# Arno Timmer
# 3
# https://www.wur.nl/en/article/msc-thesis-topic-teporingo-romerolagus-diazi-habitat-connectivity-at-landscape-level.htm
#  Teporingo (Romerolagus  diazi) habitat connectivity at landscape level
# <ul><li>Student has followed GRS20806: Geotools </li></ul>
# Requirements:
# - Student has followed GRS20806: Geotools
# FA (Frida) Ruiz Mendoza MSc
# https://www.wur.nl/en/persons/frida-ruiz-mendoza.htm
# ir. AR (Aldo) Bergsma
# https://www.wur.nl/en/persons/aldo-bergsma.htm
# https://www.wur.nl/en/article/msc-thesis-topic-the-evolution-of-land-use-in-lake-basins-insights-from-satellite-imagery-and-deep-learning-in-lake-tana-and-abaya-chamo-lake-basins..htm
#  The evolution of land-use in lake basins
# <ul><li>Advanced Earth Observation</li><li>Deep learning </li><li>Geo-scripting </li></ul>
# Requirements:
# - Advanced Earth Observation
# - Deep learning
# - Geo-scripting
# AB (Alemu) Debay
# https://www.wur.nl/en/persons/alemu-debay.htm
# dr. NE (Nandika) Tsendbazar
# https://www.wur.nl/en/persons/nandika-tsendbazar.htm
# https://www.wur.nl/en/article/mgi-thesis-topic-the-extend-and-dynamics-of-meandering-rivers-in-the-amazon-basin.htm
#  The extend and dynamics of meandering rivers in the Amazon Basin
# <ul><li>Geo-scripting course (required)</li><li>Advanced Earth Observation (required)</li><li>GEE tutorials, such as (<a data-wm-linkcode="C01" href="https://developers.google.com/earth-engine/tutorials/edu" target="_blank _blank" title="https://developers.google.com/earth-engine/tutorials/edu">https://developers.google.com/earth-engine/tutorials/edu</a>)</li></ul>
# Requirements:
# - Geo-scripting course (required)
# - Advanced Earth Observation (required)
# - GEE tutorials, such as (https://developers.google.com/earth-engine/tutorials/edu)
# dr. J (Johannes) Reiche
# https://www.wur.nl/en/persons/johannes-reiche.htm
# dr. J (Johannes) Balling MSc
# https://www.wur.nl/en/persons/johannes-balling.htm
# https://www.wur.nl/en/article/msc-thesis-topic-the-space-dilemma-can-cities-realistically-implement-the-3-30-300-greening-rule-without-sacrificing-urban-functions.htm
#  The space dilemma
# <ul><li>GIS proficiency: Familiarity with GIS is essential. You’ll work with spatial data layers, perform analyses, and create maps.</li><li>Python/R basics: Basic knowledge of Python or R is required. Some multi-criteria decision analysis models and algorithms have already been developed, and you’ll need to adapt and extend them.</li></ul>
# Requirements:
# - GIS proficiency: Familiarity with GIS is essential. You’ll work with spatial data layers, perform analyses, and create maps.
# - Python/R basics: Basic knowledge of Python or R is required. Some multi-criteria decision analysis models and algorithms have already been developed, and you’ll need to adapt and extend them.
# dr. M (Maryam) Ghodsvali
# https://www.wur.nl/en/persons/maryam-ghodsvali.htm
# https://www.wur.nl/en/article/msc-thesis-topic-temporal-vegetation-modelling-with-masked-auto-encoding.htm
#  Temporal Vegetation Modelling with Masked Auto Encoding
# <ul><li><strong></strong>Geoscripting course (required)</li><li>Deep Learning Course (required)</li></ul>
# Requirements:
# - Geoscripting course (required)
# - Deep Learning Course (required)
# dr. MC (Marc) Russwurm
# https://www.wur.nl/en/persons/marc-russwurm.htm
# dr. D (Dainius) Masiliunas
# https://www.wur.nl/en/persons/dainius-masiliunas.htm
# AJ (Arno) Timmer MSc
# https://www.wur.nl/en/persons/arno-timmer-1.htm
# https://www.wur.nl/en/article/msc-thesis-topic-thermoregulatory-movement-behaviour-of-african-savanna-grazers-and-mixed-feeders.htm
#  Thermoregulatory movement behaviour of African savanna grazers and mixed-feeders
# <ul><li>Programming experience (R or Python) </li><li>Experience with movement analyses by having completed e.g. Spatial and Temporal Analysis for Earth and Environment (GRS33306) or Data Science for Ecology (WEC33806)</li></ul>
# Requirements:
# - Programming experience (R or Python)
# - Experience with movement analyses by having completed e.g. Spatial and Temporal Analysis for Earth and Environment (GRS33306) or Data Science for Ecology (WEC33806)
# dr. JAJ (Jasper) Eikelboom
# https://www.wur.nl/en/persons/jasper-eikelboom.htm
# https://www.wur.nl/en/article/msc-thesis-topic-topic-modeling-of-mgi-msc-research-on-the-dutch-landscape.htm
#  Topic Modeling of MGI MSc Research on the Dutch Landscape
# <ul><li>Geo-information Tools (optional)</li><li>Geo Scripting (required)</li><li>Strong Python scripting skills</li></ul>
# Requirements:
# - Geo-information Tools (optional)
# - Geo Scripting (required)
# - Strong Python scripting skills
# dr. JAM (Jennifer) Koch
# https://www.wur.nl/en/persons/jennifer-koch.htm
# https://www.wur.nl/en/article/msc-thesis-topic-toward-efficient-forest-monitoring-optimizing-sample-based-approaches-for-repeated-redd-reporting.htm
#  Toward Efficient Forest Monitoring
# <ul><li><strong></strong>Geodata processing (geoscripting, geotools)</li><li>Statistical skills (e.g., using R or Python) or strong motivation to learn it.</li></ul>
# Requirements:
# - Geodata processing (geoscripting, geotools)
# - Statistical skills (e.g., using R or Python) or strong motivation to learn it.
# dr. NE (Nandika) Tsendbazar
# https://www.wur.nl/en/persons/nandika-tsendbazar.htm
# prof.dr.ir. S (Sytze) de Bruin
# https://www.wur.nl/en/persons/sytze-de-bruin-1.htm
# https://www.wur.nl/en/article/msc-thesis-topic-tree-species-identification-in-complex-tropical-rainforest-using-uav-based-multisensor-approach.htm
#  Tree species identification in complex tropical rainforest using UAV based multisensor approach
# <ul><li>Advance Earth Observation </li><li>Machine Learning </li><li>R and Python</li></ul>
# Requirements:
# - Advance Earth Observation
# - Machine Learning
# - R and Python
# M (Mudassar) Umar MSc
# https://www.wur.nl/en/persons/mudassar-umar-1.htm
# Promovendus
# Laboratory of Geo-information Science and Remote Sensing
# Mudassar Umar
# 1
# prof.dr. KM (Kirsten) de Beurs
# https://www.wur.nl/en/persons/kirsten-de-beurs-1.htm
# dr. HM (Harm) Bartholomeus
# https://www.wur.nl/en/persons/harm-bartholomeus.htm
# https://www.wur.nl/en/article/msc-thesis-topic-trend-analysis-explaining-healthy-green-cities.htm
#  Trend analysis explaining healthy green cities
# <ul><li>Proficiency with GIS</li><li>Work with large data</li><li>Python skills</li></ul>
# Requirements:
# - Proficiency with GIS
# - Work with large data
# - Python skills
# ir. AR (Aldo) Bergsma
# https://www.wur.nl/en/persons/aldo-bergsma.htm
# prof.dr. KM (Kirsten) de Beurs
# https://www.wur.nl/en/persons/kirsten-de-beurs-1.htm
# dr. JAM (Jennifer) Koch
# https://www.wur.nl/en/persons/jennifer-koch.htm
# https://www.wur.nl/en/article/msc-thesis-topic-understanding-citizens-perception-of-urban-densification-through-virtual-reality.htm
#  Understanding citizens’ perception of urban densification through virtual reality
# <ul><li>Interest in working with immersive technologies</li><li>Interest in human perception and behaviors</li><li>Interest in empirical studies and evaluations</li><li>Experience with statistical and spatial data analysis</li></ul>
# Requirements:
# - Interest in working with immersive technologies
# - Interest in human perception and behaviors
# - Interest in empirical studies and evaluations
# - Experience with statistical and spatial data analysis
# J (Jiayan) Zhao PhD
# https://www.wur.nl/en/persons/jiayan-zhao.htm
# dr. JAM (Jennifer) Koch
# https://www.wur.nl/en/persons/jennifer-koch.htm
# https://www.wur.nl/en/article/msc-thesis-topic-understanding-land-changes-uncovering-the-drivers-of-landscape-transformation.htm
#  Understanding Land Changes
# <ul><li>Geodata processing (geoscripting, geotools)</li><li>Statistical skills (e.g. using R or python) or strong motivation to learn it.</li></ul>
# Requirements:
# - Geodata processing (geoscripting, geotools)
# - Statistical skills (e.g. using R or python) or strong motivation to learn it.
# dr. NE (Nandika) Tsendbazar
# https://www.wur.nl/en/persons/nandika-tsendbazar.htm
# https://www.wur.nl/en/article/msc-thesis-topic-understanding-the-dutch-urban-landscape.htm
#  Understanding the Dutch urban landscape
# No requirements!
# AJ (Arno) Timmer MSc
# https://www.wur.nl/en/persons/arno-timmer-1.htm
# dr. M (Maryam) Ghodsvali
# https://www.wur.nl/en/persons/maryam-ghodsvali.htm
# https://www.wur.nl/en/article/msc-thesis-topic-unlocking-the-value-of-existing-reference-datasets-a-remote-sensing-approach.htm
#  Unlocking the Value of Existing Reference Datasets
# <ul><li>Advanced remote sensing </li><li>Geoscripting </li><li>Interests to work in Google Earth Engine </li></ul>
# Requirements:
# - Advanced remote sensing
# - Geoscripting
# - Interests to work in Google Earth Engine
# dr. NE (Nandika) Tsendbazar
# https://www.wur.nl/en/persons/nandika-tsendbazar.htm
# https://www.wur.nl/en/article/msc-thesis-topic-unmixing-of-satellite-based-sun-induced-fluorescence-at-scale.htm
#  Unmixing of satellite-based sun-induced fluorescence at scale
# <ul><li>Required: Geoscripting, Remote Sensing </li><li>Optional: Advanced Earth Observation, Machine Learning</li></ul>
# Requirements:
# - Required: Geoscripting, Remote Sensing
# - Optional: Advanced Earth Observation, Machine Learning
# dr. D (Dainius) Masiliunas
# https://www.wur.nl/en/persons/dainius-masiliunas.htm
# prof.dr.ir. L (Lammert) Kooistra
# https://www.wur.nl/en/persons/lammert-kooistra.htm
# dr. CL (Carlos) Camino Gonzalez
# https://www.wur.nl/en/persons/carlos-camino-gonzalez.htm
# https://www.wur.nl/en/article/msc-thesis-topic-unmixing-the-sif-signal-across-land-cover-and-spatial-scales.htm
#  Unmixing the SIF signal across land cover and spatial scales
# <ul><li>Required: Geoscripting, Remote Sensing</li><li>Optional: Advanced Earth Observation, Machine Learning</li></ul>
# Requirements:
# - Required: Geoscripting, Remote Sensing
# - Optional: Advanced Earth Observation, Machine Learning
# dr. D (Dainius) Masiliunas
# https://www.wur.nl/en/persons/dainius-masiliunas.htm
# prof.dr.ir. L (Lammert) Kooistra
# https://www.wur.nl/en/persons/lammert-kooistra.htm
# https://www.wur.nl/en/article/msc-thesis-topic-urban-green-inequality-and-its-mismatches-with-socio-environmental-demand-across-cities-in-the-netherlands.htm
#  Urban green inequality and its mismatches with socio-environmental demand across cities in the Netherlands
# <ul><li>GIS proficiency: Familiarity with GIS is essential. You’ll work with spatial data layers, perform analyses, and create maps.</li><li>Python/R basics: Basic knowledge of Python or R is required. Some statical analysis needs to be adapted.</li></ul>
# Requirements:
# - GIS proficiency: Familiarity with GIS is essential. You’ll work with spatial data layers, perform analyses, and create maps.
# - Python/R basics: Basic knowledge of Python or R is required. Some statical analysis needs to be adapted.
# dr. M (Maryam) Ghodsvali
# https://www.wur.nl/en/persons/maryam-ghodsvali.htm
# https://www.wur.nl/en/article/msc-thesis-topic-urban-green-space-and-infrastructure-dynamics-across-dutch-municipalities.htm
#  Urban Green Space and Infrastructure
# <ul><li>Geo-information Tools (optional)</li><li>Geo Scripting (required)</li><li>Strong Python scripting skills</li></ul>
# Requirements:
# - Geo-information Tools (optional)
# - Geo Scripting (required)
# - Strong Python scripting skills
# dr. JAM (Jennifer) Koch
# https://www.wur.nl/en/persons/jennifer-koch.htm
# ir. AR (Aldo) Bergsma
# https://www.wur.nl/en/persons/aldo-bergsma.htm
# https://www.wur.nl/en/article/msc-thesis-topic-urban-growth-in-central-asia-nighttime-lights.htm
#  Urban growth in Central Asia
# <ul><li><strong></strong>Good Remote Sensing background.</li><li>Geoscripting.</li><li>Affinity with urban remote sensing analysis.</li><li>Interest in land surface temperatures.</li></ul>
# Requirements:
# - Good Remote Sensing background.
# - Geoscripting.
# - Affinity with urban remote sensing analysis.
# - Interest in land surface temperatures.
# prof.dr. KM (Kirsten) de Beurs
# https://www.wur.nl/en/persons/kirsten-de-beurs-1.htm
# https://www.wur.nl/en/article/msc-thesis-topic-urban-growth-in-central-asia-impact-of-metal-roofs-on-temperature-changes.htm
#  Urban growth in Central Asia
# <ul><li>Good Remote Sensing background. </li><li>Geoscripting.</li><li>Affinity with urban remote sensing analysis. </li><li>Interest in land surface temperatures. </li></ul>
# Requirements:
# - Good Remote Sensing background.
# - Geoscripting.
# - Affinity with urban remote sensing analysis.
# - Interest in land surface temperatures.
# prof.dr. KM (Kirsten) de Beurs
# https://www.wur.nl/en/persons/kirsten-de-beurs-1.htm
# https://www.wur.nl/en/article/msc-thesis-topic-urban-scaling-of-well-being.htm
#  Urban scaling of well-being
# <ul><li>GIS proficiency: Familiarity with GIS is essential. You’ll work with spatial data layers, perform analyses, and create maps.</li><li>R basics: Performing the analyses in R is a pre.</li><li>Remote sensing (GRS20306).</li></ul>
# Requirements:
# - GIS proficiency: Familiarity with GIS is essential. You’ll work with spatial data layers, perform analyses, and create maps.
# - R basics: Performing the analyses in R is a pre.
# - Remote sensing (GRS20306).
# drs. M (Mirjam) van Hemmen
# https://www.wur.nl/en/persons/mirjam-van-hemmen.htm
# Promovendus
# Promovendus
# Laboratory of Geo-information Science and Remote Sensing
# Mirjam van Hemmen
# 1
# https://www.wur.nl/en/article/msc-thesis-topic-use-of-terrestrial-laser-scanning-to-analyse-variation-in-tree-architecture.htm
#  Use of Terrestrial Laser Scanning to analyse variation in tree architecture
# <ul><li><strong></strong>Scripting skills (e.g. R, Python) are a preference </li><li>Basic knowledge of forestry </li><li>Completion GRS32306 Advanced Earth Observation </li></ul>
# Requirements:
# - Scripting skills (e.g. R, Python) are a preference
# - Basic knowledge of forestry
# - Completion GRS32306 Advanced Earth Observation
# dr. HM (Harm) Bartholomeus
# https://www.wur.nl/en/persons/harm-bartholomeus.htm
# NE (Niamh) Kelly
# https://www.wur.nl/en/persons/niamh-kelly-1.htm
# https://www.wur.nl/en/article/msc-thesis-topic-using-sentinel-1-and-sentinel-2-for-mapping-crop-emergence.htm
#  Using Sentinel-1 and Sentinel-2 for mapping crop emergence
# <ul><li>Remote sensing (GRS-20306) </li><li>Advanced Earth Observation (GRS-32306) </li></ul>
# Requirements:
# - Remote sensing (GRS-20306)
# - Advanced Earth Observation (GRS-32306)
# ir. GJ (Gerbert) Roerink
# https://www.wur.nl/en/persons/gerbert-roerink.htm
# https://www.wur.nl/en/article/msc-thesis-topic-isolating-and-estimating-volume-of-agroforestry-systems-in-the-flevopolder.htm
#  Isolating and estimating volume of agroforestry systems in the Flevopolder
# <ul><li>Scripting skills (e.g. R, Python, MatLab) are a preference</li><li>Basic knowledge of Cloudcompare software</li><li>Completion GRS-32306 Advanced Earth Observation</li></ul>
# Requirements:
# - Scripting skills (e.g. R, Python, MatLab) are a preference
# - Basic knowledge of Cloudcompare software
# - Completion GRS-32306 Advanced Earth Observation
# dr.ir. AI (Alvaro) Lau Sarmiento MSc
# https://www.wur.nl/en/persons/alvaro-lau-sarmiento-1.htm
# MS (Maria-Franca) Dekkers MSc
# https://www.wur.nl/en/persons/maria-franca-dekkers-1.htm
# Promovendus
# WR Onderzoeker
# Soil Biology
# Maria-Franca Dekkers
# 1
